# %% [markdown]
# # Hi Amy — Video Transcription (Colab)
#
# Transcribes all 176 library videos from Google Drive using Groq Whisper and stores transcripts in the Hi Amy database so Amy can answer questions from video content.
#
# **Advantages of running here:**
# - Drive → Colab is internal Google network (fast)
# - No local download needed
# - Resumes automatically if interrupted
#
# **Run order:** Run each cell top to bottom. Start with DCA — that's Amy's core knowledge.

# %% [markdown]
# ## Step 1 — Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
print('Drive mounted.')

# %% [markdown]
# ## Step 2 — Install Dependencies

# %%
# !apt-get install -y ffmpeg -q
# !pip install -q groq psycopg2-binary sqlalchemy python-dotenv google-api-python-client google-auth
print('Dependencies installed.')

# %% [markdown]
# ## Step 3 — Set Your Credentials
#
# Fill in your values below. These stay only in this Colab session — never committed anywhere.

# %%
import os

# Groq API key (from https://console.groq.com)
GROQ_API_KEY = "gsk_YOUR_KEY_HERE"

# PostgreSQL connection string (from Render dashboard → hi-amy DB → External Database URL)
DATABASE_URL = "postgresql://user:password@host/dbname"

# Path to your service account JSON inside Drive
# Example: /content/drive/MyDrive/hi-amy-service-account.json
SERVICE_ACCOUNT_PATH = "/content/drive/MyDrive/hi-amy-service-account.json"

# Inject into environment
os.environ['GROQ_API_KEY']              = GROQ_API_KEY
os.environ['DATABASE_URL']              = DATABASE_URL
os.environ['GOOGLE_SERVICE_ACCOUNT_FILE'] = SERVICE_ACCOUNT_PATH

print('Credentials set.')

# %% [markdown]
# ## Step 4 — Copy Project Files from Drive
#
# Put `transcribe_library.py` and `database.py` in your Drive first, then update the path below.

# %%
import shutil

# Path to hi-amy folder inside your Drive
HI_AMY_DRIVE_PATH = "/content/drive/MyDrive/hi-amy"

shutil.copy(f"{HI_AMY_DRIVE_PATH}/transcribe_library.py", "/content/transcribe_library.py")
shutil.copy(f"{HI_AMY_DRIVE_PATH}/database.py",           "/content/database.py")

print('Files copied.')

# %% [markdown]
# ## Step 5 — Dry Run (verify everything connects)

# %%
# %cd /content
# !python transcribe_library.py --dry-run

# %% [markdown]
# ## Step 6 — Transcribe Videos
#
# Run cells in this order. Each is resumable — re-run if interrupted and it skips already-done videos.

# %%
# 1. DCA — Ready to Launch (most important — core curriculum)
# !python transcribe_library.py --category "Digital Course Academy" --subcategory "Ready to Launch"

# %%
# 2. DCA — Start from Scratch
# !python transcribe_library.py --category "Digital Course Academy" --subcategory "Start from Scratch"

# %%
# 3. DCA — Bonus (Q&As with Amy and Dave)
# !python transcribe_library.py --category "Digital Course Academy" --subcategory "Bonus"

# %%
# 4. DCA — Grow Your Audience
# !python transcribe_library.py --category "Digital Course Academy" --subcategory "Grow Your Audience"

# %%
# 5. DCA — Getting Started
# !python transcribe_library.py --category "Digital Course Academy" --subcategory "Getting Started"

# %%
# 6. DCA — Webinars & Live
# !python transcribe_library.py --category "Digital Course Academy" --subcategory "Webinars & Live"

# %%
# 7. DCA — Build Your Course
# !python transcribe_library.py --category "Digital Course Academy" --subcategory "Build Your Course"

# %%
# 8. AI Advantage (Summit Days + Masterclasses)
# !python transcribe_library.py --category "AI Advantage"

# %%
# 9. GHL Webinar
# !python transcribe_library.py --category "GHL Webinar"

# %%
# 10. Content Week
# !python transcribe_library.py --category "Content Week"

# %%
# 11. Sales & Marketing
# !python transcribe_library.py --category "Sales & Marketing"

# %% [markdown]
# ## Done
#
# After each batch completes, Hi Amy immediately uses the new transcripts — no redeployment needed.
#
# To transcribe one specific video:
# ```
# !python transcribe_library.py --file-id THE_FILE_ID
# ```
